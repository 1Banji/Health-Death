# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats

# %%
df1 = pd.read_csv('analytic_data2019.csv', low_memory=False)
xcl = pd.ExcelFile('2019_County_Health_Rankings_Data_v2.xls')

# %%
outcomes_fact_r = pd.read_excel(xcl, sheet_name='Outcomes & Factors Rankings')

# %%
outcomes_fact_r.columns = list(outcomes_fact_r.iloc[0])
outcomes_fact_r.drop([0],inplace=True)

# %%
outcomes_fact_r.head()
# Out:
#     FIPS    State   County # of Ranked Counties Rank Quartile Rank Quartile
# 1  01001  Alabama  Autauga                   67    7        1   11        1
# 2  01003  Alabama  Baldwin                   67    2        1    3        1
# 3  01005  Alabama  Barbour                   67   33        2   58        4
# 4  01007  Alabama     Bibb                   67   40        3   29        2
# 5  01009  Alabama   Blount                   67   22        2   16        1

# %%
outcomes_fact_subr = pd.read_excel(xcl, sheet_name='Outcomes & Factors SubRankings')
outcomes_fact_subr.columns = list(outcomes_fact_subr.iloc[0])
outcomes_fact_subr.drop([0],inplace=True)

# %%
outcomes_fact_subr.head()
# Out:
#     FIPS    State   County # of Ranked Counties Rank Quartile Rank Quartile  \
# 1  01001  Alabama  Autauga                   67    8        1    5        1
# 2  01003  Alabama  Baldwin                   67    3        1    4        1
# 3  01005  Alabama  Barbour                   67   14        1   48        3
# 4  01007  Alabama     Bibb                   67   47        3   24        2
# 5  01009  Alabama   Blount                   67   36        3   14        1
#
#   Rank Quartile Rank Quartile Rank Quartile Rank Quartile
# 1   15        1   14        1    5        1   50        3
# 2    3        1    4        1    3        1   62        4
# 3   53        4   30        2   61        4   32        2
# 4   38        3   16        1   38        3   31        2
# 5   10        1   41        3   15        1   53        4

# %%
ranked_measure = pd.read_excel(xcl, sheet_name='Ranked Measure Data')
ranked_measure.columns = list(ranked_measure.iloc[0])
ranked_measure.drop([0],inplace=True)

# %%
ranked_measure.head()
# Out:
#     FIPS    State   County Years of Potential Life Lost Rate 95% CI - Low  \
# 1  01001  Alabama  Autauga                           8824.06      7935.33
# 2  01003  Alabama  Baldwin                           7224.63      6794.13
# 3  01005  Alabama  Barbour                           9586.17      8200.12
# 4  01007  Alabama     Bibb                           11783.5        10160
# 5  01009  Alabama   Blount                           10908.1      9895.58
#
#   95% CI - High Quartile YPLL Rate (Black) YPLL Rate (Hispanic)  \
# 1       9712.79        1           10471.3                  NaN
# 2       7655.14        1           10042.5              3086.61
# 3       10972.2        1           11332.6                  NaN
# 4       13407.1        3           14812.5                  NaN
# 5       11920.6        3               NaN              5619.65
#
#   YPLL Rate (White)  ... 95% CI - High Quartile % Drive Alone (Black)  \
# 1           8706.66  ...       88.9008        3                82.722
# 2           7277.78  ...       86.5707        2               84.9219
# 3           7309.64  ...       85.7693        1               80.1547
# 4           11327.6  ...       90.6773        3                   NaN
# 5             11336  ...       88.8468        3                   NaN
#
#   % Drive Alone (Hispanic) % Drive Alone (White) # Workers who Drive Alone  \
# 1                      NaN                 83.71                     20911
# 2                  68.3439               83.7991                     74415
# 3                      NaN               86.2453                      7242
# 4                      NaN                   NaN                      6930
# 5                  81.7672               83.4145                     18426
#
#   % Long Commute - Drives Alone 95% CI - Low 95% CI - High Quartile
# 1                          38.3      34.3627       42.2373        3
# 2                          40.5      38.1835       42.8165        3
# 3                          33.8      28.8672       38.7328        2
# 4                          48.6      40.3108       56.8892        4
# 5                          59.7      55.4807       63.9193        4
#
# [5 rows x 162 columns]

# %%
add_measure = pd.read_excel(xcl, sheet_name='Additional Measure Data')
add_measure.columns = list(add_measure.iloc[0])
add_measure.drop([0],inplace=True)

# %%
add_measure.head()
# Out:
#     FIPS    State   County Life Expectancy 95% CI - Low 95% CI - High  \
# 1  01001  Alabama  Autauga         76.3306      75.5541       77.1071
# 2  01003  Alabama  Baldwin         78.5995      78.2084       78.9906
# 3  01005  Alabama  Barbour         75.7795      74.6394       76.9196
# 4  01007  Alabama     Bibb         73.9283      72.6246       75.2319
# 5  01009  Alabama   Blount         74.5978       73.811       75.3845
#
#   Life Expectancy (Black) Life Expectancy (Hispanic) Life Expectancy (White)  \
# 1                 74.6006                        NaN                 76.3372
# 2                 75.6289                    98.0399                  78.537
# 3                 74.2402                        NaN                 77.5684
# 4                 72.2947                        NaN                 74.1095
# 5                     NaN                    78.5771                 74.0982
#
#   # Deaths  ... % Hispanic # Non-Hispanic White % Non-Hispanic White  \
# 1      815  ...    2.85745                41336              74.4739
# 2     2827  ...     4.5502               176582              83.0474
# 3      451  ...    4.20657                11613              45.9557
# 4      445  ...    2.63808                16842              74.2986
# 5     1050  ...     9.5651                50439              86.9443
#
#   # Not Proficient in English % Not Proficient in English 95% CI - Low  \
# 1                         430                    0.828548     0.422472
# 2                         872                    0.454512     0.282144
# 3                         297                     1.19927     0.580536
# 4                          84                    0.394348            0
# 5                        1013                        1.87      1.36418
#
#   95% CI - High % Female # Rural  % Rural
# 1       1.23462  51.3422   22921  42.0022
# 2       0.62688  51.4528   77060  42.2791
# 3       1.81801  47.2299   18613  67.7896
# 4      0.933361  46.4531   15663  68.3526
# 5       2.37583  50.6886   51562  89.9515
#
# [5 rows x 111 columns]

# %%
add_measure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3142 entries, 1 to 3142
# Columns: 111 entries, FIPS to % Rural
# dtypes: object(111)
# memory usage: 2.7+ MB

# %%
df1.drop([0],inplace=True)
df1.head()
# Out:
#   State FIPS Code County FIPS Code 5-digit FIPS Code State Abbreviation  \
# 1              00              000             00000                 US
# 2              01              000             01000                 AL
# 3              01              001             01001                 AL
# 4              01              003             01003                 AL
# 5              01              005             01005                 AL
#
#              Name Release Year County Ranked (Yes=1/No=0)  \
# 1   United States         2019                        NaN
# 2         Alabama         2019                        NaN
# 3  Autauga County         2019                          1
# 4  Baldwin County         2019                          1
# 5  Barbour County         2019                          1
#
#   Premature death raw value Premature death numerator  \
# 1               6900.630354                   3745538
# 2              9917.2328984                     80440
# 3              8824.0571232                       815
# 4              7224.6321603                      2827
# 5               9586.165037                       451
#
#   Premature death denominator  ... Male population 18-44 raw value  \
# 1                   908266078  ...                             NaN
# 2                    13636816  ...                             NaN
# 3                      156132  ...                             NaN
# 4                      576496  ...                             NaN
# 5                       72222  ...                             NaN
#
#   Male population 45-64 raw value Male population 65+ raw value  \
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# 5                             NaN                           NaN
#
#   Total male population raw value Female population 0-17 raw value  \
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
#
#   Female population 18-44 raw value Female population 45-64 raw value  \
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# 5                               NaN                               NaN
#
#   Female population 65+ raw value Total female population raw value  \
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
# 5                             NaN                               NaN
#
#   Population growth raw value
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
#
# [5 rows x 534 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3194 entries, 1 to 3194
# Columns: 534 entries, State FIPS Code to Population growth raw value
# dtypes: object(534)
# memory usage: 13.0+ MB

# %%
life_exp = add_measure[['FIPS','State','County','Life Expectancy', '% Frequent Physical Distress',
                       '% Frequent Mental Distress', '% Diabetic', '% Food Insecure',
                        '% Insufficient Sleep', 'Household Income', '% Homeowners',
                       '% Severe Housing Cost Burden', 'Population']]
life_exp.head()
# Out:
#     FIPS    State   County Life Expectancy % Frequent Physical Distress  \
# 1  01001  Alabama  Autauga         76.3306                      12.8244
# 2  01003  Alabama  Baldwin         78.5995                       12.622
# 3  01005  Alabama  Barbour         75.7795                      16.2162
# 4  01007  Alabama     Bibb         73.9283                       13.163
# 5  01009  Alabama   Blount         74.5978                      13.7201
#
#   % Frequent Mental Distress % Diabetic % Food Insecure % Insufficient Sleep  \
# 1                    12.6384       14.2            13.4              35.9054
# 2                    12.8226       11.3            12.3              33.3059
# 3                    14.6323         18            23.2              38.5632
# 4                     12.854       14.9            15.8              38.1489
# 5                    13.8279       14.3              11               35.945
#
#   Household Income % Homeowners % Severe Housing Cost Burden Population
# 1            58343      73.2877                      12.6452      55504
# 2            56607      72.8593                      12.7959     212628
# 3            32490      62.5068                      13.5868      25270
# 4            45795      75.3615                      8.73389      22668
# 5            48253       78.521                       8.1945      58013

# %%
factors = ranked_measure[['FIPS',
                         '% Fair/Poor',
                         '% LBW', '% Smokers', '% Obese', 'Food Environment Index',
                         '% Physically Inactive', '% With Access', '% Excessive Drinking',
                         '% Alcohol-Impaired','Chlamydia Rate', 'Teen Birth Rate', '% Uninsured',
                          'Dentist Rate', 'MHP Rate',
                         'MHP Ratio', 'Preventable Hosp. Rate', '% Screened', '% Vaccinated',
                         'Graduation Rate', '% Some College', '% Unemployed', '% Children in Poverty',
                          'Income Ratio', '% Single-Parent Households', 'Association Rate',
                          'Injury Death Rate', 'Average Daily PM2.5',
                         'Presence of violation', '% Severe Housing Problems','% Drive Alone',
                         '% Long Commute - Drives Alone']]

# %%
print('Factors shape:', factors.shape)
print('Life Expectancy shape:', life_exp.shape)
# Out:
# Factors shape: (3142, 32)
# Life Expectancy shape: (3142, 13)

# %%
df_merged = life_exp.merge(factors, how='left',on='FIPS')

# %%
df_merged.dropna(subset=['Life Expectancy'], inplace=True)
df_merged.drop(['MHP Rate', 'MHP Ratio'],axis=1, inplace=True)

# %%
df_final = df_merged.dropna()
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2734 entries, 0 to 3141
# Data columns (total 42 columns):
# FIPS                             2734 non-null object
# State                            2734 non-null object
# County                           2734 non-null object
# Life Expectancy                  2734 non-null object
# % Frequent Physical Distress     2734 non-null object
# % Frequent Mental Distress       2734 non-null object
# % Diabetic                       2734 non-null object
# % Food Insecure                  2734 non-null object
# % Insufficient Sleep             2734 non-null object
# Household Income                 2734 non-null object
# % Homeowners                     2734 non-null object
# % Severe Housing Cost Burden     2734 non-null object
# Population                       2734 non-null object
# % Fair/Poor                      2734 non-null object
# % LBW                            2734 non-null object
# % Smokers                        2734 non-null object
# % Obese                          2734 non-null object
# Food Environment Index           2734 non-null object
# % Physically Inactive            2734 non-null object
# % With Access                    2734 non-null object
# % Excessive Drinking             2734 non-null object
# % Alcohol-Impaired               2734 non-null object
# Chlamydia Rate                   2734 non-null object
# Teen Birth Rate                  2734 non-null object
# % Uninsured                      2734 non-null object
# Dentist Rate                     2734 non-null object
# Preventable Hosp. Rate           2734 non-null object
# % Screened                       2734 non-null object
# % Vaccinated                     2734 non-null object
# Graduation Rate                  2734 non-null object
# % Some College                   2734 non-null object
# % Unemployed                     2734 non-null object
# % Children in Poverty            2734 non-null object
# Income Ratio                     2734 non-null object
# % Single-Parent Households       2734 non-null object
# Association Rate                 2734 non-null object
# Injury Death Rate                2734 non-null object
# Average Daily PM2.5              2734 non-null object
# Presence of violation            2734 non-null object
# % Severe Housing Problems        2734 non-null object
# % Drive Alone                    2734 non-null object
# % Long Commute - Drives Alone    2734 non-null object
# dtypes: object(42)
# memory usage: 918.5+ KB

# %% [markdown]
# Our aim to create a model to predict Life Expectancy by counties in the United States.
# Target value = Life Expectancy.
#
# It is a Regression Task that we will be using independent variables from our data as predictors. We will follow feature and model selection process to reach a final model which will predict Life Expectancy most accuratly.

# %%
#Getting data with numerical columns 
num_col = []
for i in df_final.columns:
    if (type(df_final[i][0]) != str):
        num_col.append(i)
num_col
# Out:
# ['Life Expectancy',
#  '% Frequent Physical Distress',
#  '% Frequent Mental Distress',
#  '% Diabetic',
#  '% Food Insecure',
#  '% Insufficient Sleep',
#  'Household Income',
#  '% Homeowners',
#  '% Severe Housing Cost Burden',
#  'Population',
#  '% Fair/Poor',
#  '% LBW',
#  '% Smokers',
#  '% Obese',
#  'Food Environment Index',
#  '% Physically Inactive',
#  '% With Access',
#  '% Excessive Drinking',
#  '% Alcohol-Impaired',
#  'Chlamydia Rate',
#  'Teen Birth Rate',
#  '% Uninsured',
#  'Dentist Rate',
#  'Preventable Hosp. Rate',
#  '% Screened',
#  '% Vaccinated',
#  'Graduation Rate',
#  '% Some College',
#  '% Unemployed',
#  '% Children in Poverty',
#  'Income Ratio',
#  '% Single-Parent Households',
#  'Association Rate',
#  'Injury Death Rate',
#  'Average Daily PM2.5',
#  '% Severe Housing Problems',
#  '% Drive Alone',
#  '% Long Commute - Drives Alone']

# %%
num = df_final[num_col].astype('float64')
num.head()
# Out:
#    Life Expectancy  % Frequent Physical Distress  % Frequent Mental Distress  \
# 0        76.330589                     12.824434                   12.638357
# 1        78.599498                     12.622002                   12.822558
# 2        75.779457                     16.216160                   14.632311
# 3        73.928271                     13.162968                   12.854036
# 4        74.597767                     13.720057                   13.827943
#
#    % Diabetic  % Food Insecure  % Insufficient Sleep  Household Income  \
# 0        14.2             13.4             35.905406           58343.0
# 1        11.3             12.3             33.305868           56607.0
# 2        18.0             23.2             38.563167           32490.0
# 3        14.9             15.8             38.148865           45795.0
# 4        14.3             11.0             35.945010           48253.0
#
#    % Homeowners  % Severe Housing Cost Burden  Population  ...  % Unemployed  \
# 0     73.287736                     12.645206     55504.0  ...      3.863522
# 1     72.859338                     12.795922    212628.0  ...      3.988336
# 2     62.506800                     13.586765     25270.0  ...      5.900923
# 3     75.361481                      8.733889     22668.0  ...      4.385140
# 4     78.521025                      8.194495     58013.0  ...      4.021393
#
#    % Children in Poverty  Income Ratio  % Single-Parent Households  \
# 0                   19.3      4.636664                   24.700097
# 1                   14.7      4.518560                   25.184091
# 2                   50.3      5.755063                   57.215743
# 3                   27.3      4.254594                   29.565404
# 4                   18.5      4.126883                   29.569733
#
#    Association Rate  Injury Death Rate  Average Daily PM2.5  \
# 0         12.631731          74.031808                 11.7
# 1         10.692213          69.374289                 10.3
# 2          8.472944          72.900134                 11.5
# 3         10.157665         100.077937                 11.2
# 4          9.011507         105.197227                 11.7
#
#    % Severe Housing Problems  % Drive Alone  % Long Commute - Drives Alone
# 0                  14.954646      85.965057                           38.3
# 1                  13.831725      84.719423                           40.5
# 2                  15.455531      83.404353                           33.8
# 3                  10.960854      86.365902                           48.6
# 4                  10.401153      86.792275                           59.7
#
# [5 rows x 38 columns]

# %%
#Checking for duplicates
num.duplicated().sum()
# Out:
# 0

# %% [markdown]
# At this point we will create a test set and put it aside to prevent any possible generalization error
# and data snooping bias in our models

# %% [markdown]
# For this purpose we will use sklearn train_test_split function which allow us to plit our data into multiple
# datasets

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(num, test_size=0.2, random_state=42)

# %%
train_set.corrwith(num['Life Expectancy']).abs().sort_values(ascending=False)
# Out:
# Life Expectancy                  1.000000
# % Smokers                        0.732672
# % Frequent Mental Distress       0.720600
# % Frequent Physical Distress     0.704664
# Teen Birth Rate                  0.701876
# % Diabetic                       0.693410
# % Children in Poverty            0.692781
# Household Income                 0.681047
# % Physically Inactive            0.680257
# % Fair/Poor                      0.672703
# % Food Insecure                  0.628603
# Injury Death Rate                0.623388
# % Excessive Drinking             0.598265
# % Some College                   0.586360
# % Obese                          0.580579
# % Insufficient Sleep             0.542177
# Food Environment Index           0.539412
# % LBW                            0.526232
# % Single-Parent Households       0.507130
# Preventable Hosp. Rate           0.503246
# % With Access                    0.442783
# % Screened                       0.412870
# % Unemployed                     0.410511
# Income Ratio                     0.371004
# % Drive Alone                    0.333023
# % Vaccinated                     0.326413
# Dentist Rate                     0.305997
# Chlamydia Rate                   0.298329
# % Uninsured                      0.284572
# Average Daily PM2.5              0.261846
# Population                       0.230486
# % Long Commute - Drives Alone    0.099019
# Graduation Rate                  0.060484
# Association Rate                 0.060472
# % Severe Housing Cost Burden     0.036502
# % Alcohol-Impaired               0.029589
# % Homeowners                     0.027026
# % Severe Housing Problems        0.013500
# dtype: float64

# %%
#Let's get top 5 attributes with the highest correlation to Life Expectancy and plot a heatmap  
df_five = train_set[['Life Expectancy', '% Smokers', '% Frequent Mental Distress', 
               '% Frequent Physical Distress', 'Teen Birth Rate', '% Diabetic']]

# %%
df_five.corr()
# Out:
#                               Life Expectancy  % Smokers  \
# Life Expectancy                      1.000000  -0.732672
# % Smokers                           -0.732672   1.000000
# % Frequent Mental Distress          -0.720600   0.821389
# % Frequent Physical Distress        -0.704664   0.808856
# Teen Birth Rate                     -0.701876   0.580801
# % Diabetic                          -0.693410   0.677739
#
#                               % Frequent Mental Distress  \
# Life Expectancy                                -0.720600
# % Smokers                                       0.821389
# % Frequent Mental Distress                      1.000000
# % Frequent Physical Distress                    0.952134
# Teen Birth Rate                                 0.611447
# % Diabetic                                      0.699879
#
#                               % Frequent Physical Distress  Teen Birth Rate  \
# Life Expectancy                                  -0.704664        -0.701876
# % Smokers                                         0.808856         0.580801
# % Frequent Mental Distress                        0.952134         0.611447
# % Frequent Physical Distress                      1.000000         0.691841
# Teen Birth Rate                                   0.691841         1.000000
# % Diabetic                                        0.656013         0.492774
#
#                               % Diabetic
# Life Expectancy                -0.693410
# % Smokers                       0.677739
# % Frequent Mental Distress      0.699879
# % Frequent Physical Distress    0.656013
# Teen Birth Rate                 0.492774
# % Diabetic                      1.000000

# %%
df_five.describe()
# Out:
#        Life Expectancy    % Smokers  % Frequent Mental Distress  \
# count      2187.000000  2187.000000                 2187.000000
# mean         77.299130    18.040793                   12.326253
# std           2.770723     3.544322                    1.819970
# min          67.607861     6.735433                    8.034557
# 25%          75.435204    15.444067                   11.014599
# 50%          77.398871    17.765218                   12.208524
# 75%          79.127439    20.494035                   13.552363
# max          94.659083    39.079703                   20.110109
#
#        % Frequent Physical Distress  Teen Birth Rate   % Diabetic
# count                   2187.000000      2187.000000  2187.000000
# mean                      12.110732        31.972609    11.740101
# std                        2.259682        14.894003     2.601259
# min                        6.936987         2.394971     3.300000
# 25%                       10.436493        20.844723     9.900000
# 50%                       11.850534        30.736358    11.700000
# 75%                       13.633334        41.691972    13.500000
# max                       20.899694       110.236220    20.900000

# %%
fig = plt.figure(figsize=(12,8))
sns.heatmap(df_five.corr().abs(), annot=True)

# %% [markdown]
# There is a high chance of multicollinearity between two independent variables %Frequent Mental Distress and
# % Frequent Physical Distress as we see from the heatmap above they are highly related to each other.

# %%
df_five.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2e0a8eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2e103ba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2e30c198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2e337748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2e367cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2e3a32e8>]],
#       dtype=object)

# %%
#Normality test
alpha = 0.05
for i in df_five.columns:
    fig = plt.figure(figsize=(12,8))
    sns.distplot(df_five[i], label=i, hist=False)
    k2, p = stats.normaltest(df_five[i])
    if p < alpha:  # null hypothesis: x comes from a normal distribution
         print("%s is not normal"%i,p)
    else:
         print("%s is normal"%i)
# Out:
# Life Expectancy is not normal 1.9494763460838107e-13
# % Smokers is not normal 2.5091547227491995e-19
# % Frequent Mental Distress is not normal 3.298412540366009e-11
# % Frequent Physical Distress is not normal 1.700472282832283e-20
# Teen Birth Rate is not normal 7.042476531675867e-30
# % Diabetic is not normal 0.0024223405498960135

# %%
for i in df_five.columns:
    fig = plt.figure(figsize=(12,8))
    sns.regplot( x=df_five[i], y=df_five['Life Expectancy'])

# %%
target = train_set['Life Expectancy']
predictors1 = train_set[['% Smokers', '% Frequent Mental Distress',
                         'Teen Birth Rate', '% Diabetic']]

# %% [markdown]
# Transformation

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled1 = scaler.fit_transform(predictors1)

# %%
df_scaled = pd.DataFrame(scaled1)
df_scaled.columns = predictors1.columns

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
lin_reg = LinearRegression()
c_val = KFold(n_splits=5, shuffle=True, random_state=42)
lin_reg.fit(scaled1, target)
scores = cross_val_score(lin_reg, scaled1, target, scoring='neg_mean_squared_error', cv=c_val)
lin_score_r2 = np.mean(cross_val_score(lin_reg, scaled1, target, scoring='r2', cv=c_val))
lin_scores_rmse = np.sqrt(-scores)

# %%
def display_scores(scores, r2):
    print('Scores: ', scores)
    print('Mean: ', scores.mean())
    print('Standard Deviation: ',scores.std())
    print('r2: ', r2)

# %%
display_scores(lin_scores_rmse,lin_score_r2)
# Out:
# Scores:  [1.44289219 1.50499586 1.5164929  1.46109424 1.66916122]
# Mean:  1.5189272829930314
# Standard Deviation:  0.0798701979680207
# r2:  0.6984766771312325

# %% [markdown]
# This is our baseline model. We will try to improve the model by adding more attributes. We will use only the attributes which has more than 0.4 correlation with Life Expectancy to keep our model as simple as possible. Before that we will check training data to make sure if there is any multicollinearity between independent variable.

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()

# %%
tree_reg.fit(scaled1, target)
scores_tree = cross_val_score(tree_reg, scaled1, target, scoring='neg_mean_squared_error', cv=10)
tree_score_r2 = np.mean(cross_val_score(tree_reg, scaled1, target, scoring='r2', cv=c_val))
tree_rmse_scores = np.sqrt(-scores_tree)
display_scores(tree_rmse_scores, tree_score_r2)
# Out:
# Scores:  [2.07139708 2.12790677 2.13485554 2.0834548  2.2040393  1.94540406
#  2.45907687 2.12234188 1.84492479 1.93755901]
# Mean:  2.093096010316888
# Standard Deviation:  0.16069187601478171
# r2:  0.3952460048018889

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(scaled1, target)
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
scores_forest = cross_val_score(forest_reg, scaled1, target, scoring='neg_mean_squared_error', cv=10)
forest_score_r2 = np.mean(cross_val_score(forest_reg, scaled1, target, scoring='r2', cv=c_val))
forest_rmse_scores = np.sqrt(-scores_forest)
display_scores(forest_rmse_scores, forest_score_r2)
# Out:
# Scores:  [1.60293323 1.51128962 1.53249149 1.66631069 1.78366845 1.56172991
#  1.85543621 1.48649975 1.54690281 1.68617581]
# Mean:  1.623343797265401
# Standard Deviation:  0.11617123447475904
# r2:  0.649778313126123
